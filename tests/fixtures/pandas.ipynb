# %%
import pandas as pd

df = pd.DataFrame({'Name': ['Alice', 'Bob'], 'Age': [25, 30]})
df.head()
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
grouped
# Out:
# Region  Product
# East    A         10  3
#         B         12  4
# West    C          8  2
